# %%
# !pip install tensorflow==1.14

# !pip install keras==2.2.4

# !pip install 'h5py==2.10.0'

# !pip install pydicom
# Out:
# ...
#      |████████████████████████████████| 109.3 MB 1.1 MB/s
# ...
#      |████████████████████████████████| 488 kB 70.8 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 72.6 MB/s
# ...
#      |████████████████████████████████| 50 kB 8.6 MB/s
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.7.0
#     Uninstalling tensorboard-2.7.0:
#       Successfully uninstalled tensorboard-2.7.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# Required packages
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pylab as plt
import pydicom
import os
import cv2
import tensorflow.keras as keras
from os import listdir
from os.path import isfile, join


import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/My Drive/GL AIML/Chexnet model/CheXNet-Keras-master')

# %%
# !ls
# Out:
# augmenter.py	 config.ini   generator.py  README.md	      utility.py
# callback.py	 data	      LICENSE	    requirements.txt  weights.py
# cam_example.png  data_new     models	    test.py
# cam.py		 experiments  __pycache__   train.py

# %%
def plot(index):
    fig,ax = plt.subplots(1)

    ds = dicom.dcmread(starting_path + train_label['patientId'][index] + '.dcm')
    # Display the image
    ax.imshow(ds.pixel_array, cmap=pylab.cm.binary)

    rect = patches.Rectangle((data['x'][index], 
                               data['y'][index]), 
                              data['width'][index], 
                              data['height'][index],
                              linewidth=2, edgecolor='r', facecolor='none')
    ax.add_patch(rect)

    plt.show()

# %% [markdown]
# ## Conversion to png from dicom

# %%
# inputdir = '/content/drive/My Drive/GL AIML/11. Capstone/stage_2_train_images/'
# outdir = './data_new/images/'
# # os.mkdir(outdir)

# train_list = [ f for f in  os.listdir(inputdir) ]

# for f in train_list[26811:]:
#     ds = pydicom.read_file(inputdir + f) # read dicom image
#     img = ds.pixel_array # get image
#     cv2.imwrite(outdir + f.replace('.dcm','.png'),img) # write jpg image

# %%
# img_count = [ g for g in  os.listdir('./data_new/images_unscaled/') ]

# %%
img_scaled = [ g for g in  os.listdir('./data_new/images/') ]

print(len(img_scaled))
# Out:
# 26811

# %%
# train_list_2 = [ k for k in  os.listdir(inputdir) ]

# %%
# print(len(train_list_2))

# %%
# print(len(img_count))

# img_count[0]
# Out:
# 26811
# '16d4d825-3334-424d-9bfe-0e6fb28c678a.png'

# %%
# img = cv2.imread('./data_new/images_unscaled/'+ img_count[0])

# img.shape
# Out:
# (1024, 1024, 3)

# %%
# plt.imshow(img)
# plt.show()

# %% [markdown]
# ## Conversion from 1024 * 1024 to 224 * 224 which is required for chexnet

# %%
# for image in img_count[26599:]:
#     image_array = cv2.imread('./data_new/images_unscaled/'+ image)
#     image_resized = cv2.resize(image_array, (224, 224))
#     cv2.imwrite("./data_new/images/" + image, image_resized)

# %%
img2 = cv2.imread('./data_new/images/'+ img_scaled[0])

img2.shape
# Out:
# (224, 224, 3)

# %%
plt.imshow(img2)
plt.show()

# %%
img2 = cv2.imread('./data_new/images/00436515-870c-4b36-a041-de91049b9ab4.png')
plt.imshow(img2)
plt.show()

# %%
img3 = cv2.imread('./data_new/images/09d2a8d3-3ef9-4e91-8abe-d1c127747905.png')
plt.imshow(img3)
plt.show()

# %%
# !python train.py
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !python test.py
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !python cam.py
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !python cam.py
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
import pickle


with open('./experiments/1/history.pkl', 'rb') as f:
  a = pickle.load(f)

# %%
a
# Out:
# {'auroc': {'Pneumonia_no': [0.7306356837606839,
#    0.8473112535612535,
#    0.8514066951566952,
#    0.863826566951567,
#    0.8630252849002849,
#    0.8673878205128204,
#    0.8652510683760685,
#    0.8717948717948717,
#    0.8778044871794871,
#    0.8807425213675214],
#   'Pneumonia_yes': [0.6655092592592593,
#    0.8468215811965812,
#    0.8535434472934473,
#    0.8631588319088319,
#    0.862758190883191,
#    0.8682336182336183,
#    0.8674768518518519,
#    0.8735754985754987,
#    0.8810096153846153,
#    0.8837250712250713]},
#  'history': {'loss': [0.5401111349463463,
#    0.4735434100031853,
#    0.4277990564703941,
#    0.37790120467543603,
#    0.3815131813287735,
#    0.4003607288002968,
#    0.3791555315256119,
#    0.38524449020624163,
#    0.38736497312784196,
#    0.3817904144525528],
#   'lr': [0.001,
#    0.001,
#    0.001,
#    0.000100000005,
#    0.000100000005,
#    1.0000001e-05,
#    1.0000001e-05,
#    1.0000001e-05,
#    1.0000001e-05,
# ...

# %% [markdown]
# ### Loss vs epochs

# %%
plt.step(range(1,11),a['history']['loss'], where='mid')
plt.step(range(1,11),a['history']['val_loss'], where='mid')
plt.legend(['loss','val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.show()

# %% [markdown]
# ### AUROC vs epochs

# %%
plt.step(range(1,11),a['auroc']['Pneumonia_no'], where='mid')
plt.step(range(1,11),a['auroc']['Pneumonia_yes'], where='mid')
plt.legend(['label 0','label 1'])
plt.ylabel('AUROC')
plt.xlabel('Epochs')
plt.show()
